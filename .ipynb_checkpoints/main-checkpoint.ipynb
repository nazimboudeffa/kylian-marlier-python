# %%
import pandas as pd

# Chargement du fichier CSV (remplace 'ton_fichier.csv' par le nom réel si besoin)
df = pd.read_csv('06_2025.csv')

# Affichage des premières lignes
print(df.head())
# Out:
#          date    pair  signal
# 0  14/06/2025  AUDJPY      53
# 1  14/06/2025  GBPUSD      62
# 2  14/06/2025  CADCHF      70
# 3  14/06/2025  GBPJPY     -64
# 4  14/06/2025  AUDCHF      31

# %%
# Infos de base
print(df.info())

# Statistiques descriptives
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    37 non-null     object
#  1   pair    37 non-null     object
#  2   signal  37 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 1020.0+ bytes
# None
#            signal
# count   37.000000
# mean    12.081081
# std     61.875941
# min    -67.000000
# 25%    -65.000000
# 50%     31.000000
# 75%     57.000000
# max    136.000000

# %%
# Moyenne du signal
print("Moyenne du signal :", df['signal'].mean())

# Valeur max et min
print("Signal maximum :", df['signal'].max())
print("Signal minimum :", df['signal'].min())

# Répartition positive vs négative
print("Signaux positifs :", (df['signal'] > 0).sum())
print("Signaux négatifs :", (df['signal'] < 0).sum())
# Out:
# Moyenne du signal : 12.08108108108108
# Signal maximum : 136
# Signal minimum : -67
# Signaux positifs : 24
# Signaux négatifs : 13

# %%
# Paires avec les signaux les plus forts (positifs ou négatifs)
df_sorted = df.sort_values(by='signal', ascending=False)
print(df_sorted)
# Out:
#           date    pair  signal
# 10  14/06/2025  USDCHF     136
# 8   14/06/2025  CHFJPY     100
# 14  21/06/2025  GBPAUD      81
# 35  28/06/2025  EURJPY      80
# 22  21/06/2025  GBPJPY      71
# 2   14/06/2025  CADCHF      70
# 29  28/06/2025  USDCAD      67
# 1   14/06/2025  GBPUSD      62
# 32  28/06/2025  CADCHF      60
# 12  14/06/2025  GBPCAD      57
# 33  28/06/2025  GBPJPY      56
# 27  28/06/2025  GBPUSD      55
# 0   14/06/2025  AUDJPY      53
# 16  21/06/2025  EURCAD      44
# 30  28/06/2025  GBPUSD      44
# 20  21/06/2025  AUDJPY      43
# 26  28/06/2025  AUDUSD      37
# 17  21/06/2025  EURGBP      33
# 4   14/06/2025  AUDCHF      31
# 13  21/06/2025  CADCHF      31
# 19  21/06/2025  EURUSD      31
# 6   14/06/2025  AUDUSD      20
# 23  21/06/2025  NZDCHF      20
# 25  21/06/2025  GBPCHF      15
# 3   14/06/2025  GBPJPY     -64
# 24  21/06/2025  USDJPY     -64
# 7   14/06/2025  EURUSD     -64
# 11  14/06/2025  AUDJPY     -65
# 15  21/06/2025  GBPJPY     -65
# 34  28/06/2025  USDCAD     -65
# 36  28/06/2025  EURCAD     -65
# 18  21/06/2025  GBPUSD     -65
# 31  28/06/2025  GBPAUD     -65
# 5   14/06/2025  USDJPY     -67
# 9   14/06/2025  GBPNZD     -67
# 28  28/06/2025  EURJPY     -67
# 21  21/06/2025  EURAUD     -67

# %%
# Nombre de paires distinctes
nb_pairs_uniques = df['pair'].nunique()
print("Nombre de paires distinctes :", nb_pairs_uniques)
# Out:
# Nombre de paires distinctes : 20

# %%
# Fréquence des paires tradées
frequences = df['pair'].value_counts()
print(frequences)
# Out:
# pair
# GBPUSD    4
# GBPJPY    4
# AUDJPY    3
# CADCHF    3
# USDJPY    2
# AUDUSD    2
# EURUSD    2
# GBPAUD    2
# USDCAD    2
# EURJPY    2
# EURCAD    2
# AUDCHF    1
# GBPCAD    1
# USDCHF    1
# GBPNZD    1
# CHFJPY    1
# EURAUD    1
# EURGBP    1
# GBPCHF    1
# NZDCHF    1
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

frequences.plot(kind='bar', figsize=(10, 5))
plt.title('Fréquence des paires tradées')
plt.xlabel('Paire de devises')
plt.ylabel('Nombre de signaux')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Total des pips
total_pips = df['signal'].sum()
print("Total de pips :", total_pips)
# Out:
# Total de pips : 447
