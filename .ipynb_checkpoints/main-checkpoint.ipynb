# %%
import pandas as pd

# Chargement du fichier CSV (remplace 'ton_fichier.csv' par le nom réel si besoin)
df = pd.read_csv('202507.csv')

# Affichage des premières lignes
print(df.head())
# Out:
#          date    pair  signal
# 0  05/07/2025  GBPCHF     117
# 1  05/07/2025  EURJPY      65
# 2  05/07/2025  NZDCAD      25
# 3  05/07/2025  USDJPY     -65
# 4  05/07/2025  CADJPY      74

# %%
# Infos de base
print(df.info())

# Statistiques descriptives
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    38 non-null     object
#  1   pair    38 non-null     object
#  2   signal  38 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 1.0+ KB
# None
#            signal
# count   38.000000
# mean    19.789474
# std     54.660207
# min    -69.000000
# 25%    -34.500000
# 50%     35.000000
# 75%     50.750000
# max    117.000000

# %%
# Moyenne du signal
print("Moyenne du signal :", df['signal'].mean())

# Valeur max et min
print("Signal maximum :", df['signal'].max())
print("Signal minimum :", df['signal'].min())

# Répartition positive vs négative
print("Signaux positifs :", (df['signal'] > 0).sum())
print("Signaux négatifs :", (df['signal'] < 0).sum())
# Out:
# Moyenne du signal : 19.789473684210527
# Signal maximum : 117
# Signal minimum : -69
# Signaux positifs : 28
# Signaux négatifs : 10

# %%
# Paires avec les signaux les plus forts (positifs ou négatifs)
df_sorted = df.sort_values(by='signal', ascending=False)
print(df_sorted)
# Out:
#           date    pair  signal
# 0   05/07/2025  GBPCHF     117
# 17  12/07/2025  GBPUSD      87
# 26  19/07/2025  EURUSD      86
# 28  19/07/2025  EURJPY      85
# 4   05/07/2025  CADJPY      74
# 24  19/07/2025  AUDNZD      68
# 1   05/07/2025  EURJPY      65
# 8   05/07/2025  EURAUD      63
# 23  12/07/2025  EURUSD      60
# 21  12/07/2025  USDJPY      51
# 37  19/07/2025  USDCAD      50
# 16  12/07/2025  GBPJPY      49
# 32  19/07/2025  EURNZD      40
# 19  12/07/2025  AUDNZD      40
# 6   05/07/2025  GBPUSD      40
# 13  12/07/2025  AUDCAD      38
# 14  12/07/2025  EURUSD      38
# 34  19/07/2025  NZDCHF      37
# 20  12/07/2025  EURCAD      35
# 12  12/07/2025  NZDCHF      35
# 30  19/07/2025  AUDCAD      35
# 9   05/07/2025  GBPJPY      35
# 5   05/07/2025  EURCHF      33
# 22  12/07/2025  USDCHF      31
# 10  05/07/2025  GBPCHF      28
# 15  12/07/2025  USDCAD      26
# 2   05/07/2025  NZDCAD      25
# 36  19/07/2025  NZDUSD      24
# 35  19/07/2025  EURJPY     -54
# 7   05/07/2025  GBPNZD     -63
# 11  05/07/2025  EURNZD     -64
# 3   05/07/2025  USDJPY     -65
# 18  12/07/2025  EURNZD     -65
# 33  19/07/2025  GBPJPY     -65
# 25  19/07/2025  GBPAUD     -66
# 27  19/07/2025  EURAUD     -66
# 31  19/07/2025  AUDJPY     -66
# 29  19/07/2025  NZDCAD     -69

# %%
# Nombre de paires distinctes
nb_pairs_uniques = df['pair'].nunique()
print("Nombre de paires distinctes :", nb_pairs_uniques)
# Out:
# Nombre de paires distinctes : 21

# %%
# Fréquence des paires tradées
frequences = df['pair'].value_counts()
print(frequences)
# Out:
# pair
# EURJPY    3
# GBPJPY    3
# EURUSD    3
# EURNZD    3
# GBPCHF    2
# AUDNZD    2
# USDJPY    2
# NZDCAD    2
# GBPUSD    2
# NZDCHF    2
# AUDCAD    2
# USDCAD    2
# EURAUD    2
# CADJPY    1
# GBPNZD    1
# EURCHF    1
# EURCAD    1
# USDCHF    1
# GBPAUD    1
# AUDJPY    1
# NZDUSD    1
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

frequences.plot(kind='bar', figsize=(10, 5))
plt.title('Fréquence des paires tradées')
plt.xlabel('Paire de devises')
plt.ylabel('Nombre de signaux')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Total des pips
total_pips = df['signal'].sum()
print("Total de pips :", total_pips)
# Out:
# Total de pips : 752
